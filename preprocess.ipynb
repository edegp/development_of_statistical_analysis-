# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from src.consts import data_path, data_file
from src.preprocess import create_feature

# japanese font
pd.set_option('display.max_columns', 40)
plt.rcParams['font.family'] = 'Meiryo UI'

df = pd.read_csv(os.path.join(data_path, data_file), encoding="cp932")
df.head()
# Out:
#           種類  価格情報区分   地域  市区町村コード 都道府県名 市区町村名  地区名  最寄駅：名称 最寄駅：距離（分）  \
# 0  宅地(土地と建物)  成約価格情報  NaN    13112   東京都  世田谷区  宇奈根    二子玉川       NaN
# 1  宅地(土地と建物)  成約価格情報  NaN    13112   東京都  世田谷区  桜上水     桜上水         5
# 2  宅地(土地と建物)  成約価格情報  NaN    13112   東京都  世田谷区  祖師谷  祖師ケ谷大蔵        20
# 3  宅地(土地と建物)  成約価格情報  NaN    13112   東京都  世田谷区  祖師谷  祖師ケ谷大蔵        20
# 4  宅地(土地と建物)  成約価格情報  NaN    13112   東京都  世田谷区  祖師谷  祖師ケ谷大蔵        20
#
#    取引価格（総額）  坪単価 面積（㎡）  取引価格（㎡単価） 土地の形状   間口 延床面積（㎡）    建築年 建物の構造   用途  \
# 0  41000000  NaN    90        NaN   NaN  NaN      80  2005年    木造  NaN
# 1  72000000  NaN    80        NaN   NaN  NaN     100  2010年    木造  NaN
# 2  51000000  NaN   105        NaN   NaN  NaN      85  2004年    木造  NaN
# 3  70000000  NaN   125        NaN   NaN  NaN      95  2016年    木造  NaN
# 4  69000000  NaN   120        NaN   NaN  NaN      95  2011年    木造  NaN
#
#   今後の利用目的 前面道路：方位 前面道路：種類  前面道路：幅員（ｍ）  都市計画  建ぺい率（％）  容積率（％）        取引時期  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21359 entries, 0 to 21358
# Data columns (total 28 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   種類          21359 non-null  object
#  1   価格情報区分      21359 non-null  object
#  2   地域          20326 non-null  object
#  3   市区町村コード     21359 non-null  int64
#  4   都道府県名       21359 non-null  object
#  5   市区町村名       21359 non-null  object
#  6   地区名         21359 non-null  object
#  7   最寄駅：名称      21341 non-null  object
#  8   最寄駅：距離（分）   21283 non-null  object
#  9   取引価格（総額）    21359 non-null  int64
#  10  坪単価         8383 non-null   float64
#  11  面積（㎡）       21359 non-null  object
#  12  取引価格（㎡単価）   8383 non-null   float64
#  13  土地の形状       20283 non-null  object
#  14  間口          18742 non-null  object
#  15  延床面積（㎡）     12551 non-null  object
#  16  建築年         12321 non-null  object
#  17  建物の構造       12436 non-null  object
#  18  用途          11392 non-null  object
# ...

# %%
for col in df.columns:
    print(col)
    print(df[col].unique())
    print(df[col].value_counts())
    print()
# Out:
# 種類
# ['宅地(土地と建物)' '宅地(土地)']
# 種類
# 宅地(土地と建物)    12976
# 宅地(土地)        8383
# Name: count, dtype: int64
#
# 価格情報区分
# ['成約価格情報' '不動産取引価格情報']
# 価格情報区分
# 不動産取引価格情報    20326
# 成約価格情報        1033
# Name: count, dtype: int64
#
# 地域
# [nan '住宅地' '商業地']
# 地域
# 住宅地    19135
# 商業地     1191
# Name: count, dtype: int64
#
# 市区町村コード
# [13112]
# 市区町村コード
# 13112    21359
# Name: count, dtype: int64
#
# 都道府県名
# ['東京都']
# 都道府県名
# 東京都    21359
# Name: count, dtype: int64
#
# 市区町村名
# ['世田谷区']
# 市区町村名
# 世田谷区    21359
# Name: count, dtype: int64
#
# 地区名
# ['宇奈根' '桜上水' '祖師谷' '千歳台' '野毛' '羽根木' '深沢' '松原' '東玉川' '南烏山' '豪徳寺' '岡本' '上用賀'
#  '北沢' '喜多見' '給田' '経堂' '桜' '成城' '宮坂' '上祖師谷' '桜新町' '代田' '船橋' '中町' '奥沢' '粕谷'
#  '上馬' '上野毛' '北烏山' '駒沢' '下馬' '新町' '太子堂' '等々力' '八幡山' '梅丘' '尾山台' '野沢' '用賀'
#  '大原' '代沢' '赤堤' '池尻' '上北沢' '砧' '桜丘' '三軒茶屋' '世田谷' '玉堤' '弦巻' '三宿' '若林' '鎌田'
#  '玉川台' '瀬田' '玉川田園調布' '大蔵' '玉川']
# 地区名
# 奥沢        798
# 北烏山       742
# 深沢        716
# 成城        709
# 祖師谷       654
# 下馬        623
# 松原        613
# ...

# %%
data = create_feature(df)
data.head()
# Out:
# 5
# 20
# 20
# 20
# 5
# 20
# 10
# 20
# 20
# 20
# 20
# 15
# 15
# 5
# 20
# 10
# 5
# 5
# 15
# 15
# 15
# 20
# 20
# 20
# 15
# 15
# 20
# 15
# 20
# 15
# 15
# 20
# 10
# 10
# 15
# 10
# 20
# 15
# 20
# 5
# 5
# 5
# 5
# 15
# 20
# 25
# 10
# 20
# 10
# 15
# 5
# 15
# 10
# 15
# 10
# 15
# 15
# 5
# 10
# 5
# 10
# 5
# 5
# 10
# 10
# 5
# 10
# 10
# 10
# 25
# 20
# 20
# 15
# 10
# 10
# 20
# 20
# 20
# 20
# 20
# 10
# 10
# 25
# 15
# 5
# 10
# 10
# 15
# 15
# 15
# 15
# 10
# 10
# 5
# 10
# 10
# 5
# 25
# 20
# 20
# 20
# 20
# 10
# 15
# 25
# 10
# 10
# 15
# 20
# 15
# 10
# 10
# 5
# 5
# 5
# 10
# 15
# 15
# 5
# 10
# 10
# 10
# 10
# 10
# 15
# 5
# 20
# 10
# 25
# 15
# 10
# 15
# 20
# 20
# 10
# 5
# 15
# 25
# 10
# 10
# 10
# 10
# 15
# 15
# 20
# 10
# 10
# 10
# 10
# 5
# 5
# 10
# 15
# 20
# 15
# 15
# 15
# 5
# 10
# 15
# 25
# 15
# 25
# 15
# 15
# 10
# 15
# 20
# 10
# 25
# 10
# 15
# 5
# 15
# 15
# 25
# 5
# 5
# 15
# 15
# 15
# 10
# 10
# 5
# 10
# 15
# 5
# 10
# 10
# 5
# 5
# 10
# 15
# 15
# 20
# 15
# 10
# 15
# 15
# 5
# 15
# 15
# 10
# 10
# 10
# 10
# 10
# ...

# %%
for col in data.columns:
    print(col)
    print(data[col].isnull().sum())
    print(data[col].unique())
    print(data[col].value_counts())
    print()
# Out:
# total_price
# 0
# [   41000000    72000000    55000000    60000000    59000000    73000000
#     84000000    50000000    52000000    57000000    38000000    53000000
#     39000000    74000000    54000000    65000000    64000000   110000000
#     95000000   100000000    88000000    96000000    75000000    62000000
#     79000000    78000000    77000000    63000000    70000000   120000000
#     82000000    27000000    21000000    66000000    58000000    30000000
#     80000000    71000000   240000000   170000000    92000000    99000000
#     94000000    85000000    90000000    44000000    51000000    56000000
#     48000000   320000000   130000000    69000000    45000000    46000000
#     89000000   160000000   450000000    93000000   140000000    32000000
#     87000000    43000000   460000000   210000000    25000000    67000000
#     83000000   290000000   250000000    98000000    29000000    81000000
#    200000000    35000000    36000000    97000000    47000000    15000000
# ...

# %%
data.to_csv(os.path.join(data_path, "setagaya_propetry_deel_data_2005_2023.csv"), index=False)
